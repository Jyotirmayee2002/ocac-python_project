# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
data=pd.read_csv("C:\\Users\\DELL\\Downloads\\Unemployment_data.csv")
data
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
# 11             Himachal Pradesh        22795        75185       69.14
# ...

# %%
data.head(10)
# Out:
#       States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0  Andaman and Nicobar Islands        25047        89642       81.30
# 1               Andhra Pradesh        17195        64773       60.47
# 2            Arunachal Pradesh        15260        71366       54.34
# 3                        Assam        12803        36320       63.25
# 4                        Bihar         6415        22582       47.00
# 5                   Chandigarh        49771       136883       81.94
# 6                 Chhattisgarh        10744        48366       64.66
# 7                        Delhi        40678       161446       57.63
# 8                          Goa        43735       211570       78.18
# 9                      Gujarat        18392        85979       81.67
#
#    2011- LIT  2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  \
# 0      86.63         356        381              846              876
# ...

# %%
data.describe()
# Out:
#        2000-01-INC    2011-12-INC  2001 - LIT  2011- LIT     2001 - POP  \
# count     32.00000      32.000000   32.000000  32.000000      32.000000
# mean   19696.53125   74792.500000   69.810625  78.240312   32134.437500
# std    10191.63120   40960.182286   11.149199   8.733646   38054.631775
# min     6415.00000   22582.000000   47.000000  61.800000     356.000000
# 25%    12965.75000   47958.000000   62.950000  71.712500    2218.000000
# 50%    16418.00000   66413.000000   68.975000  77.465000   20989.500000
# 75%    22781.50000   89198.000000   78.945000  86.090000   53765.000000
# max    49771.00000  211570.000000   90.860000  94.000000  166198.000000
#
#            2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# count      32.000000         32.00000        32.000000    32.000000
# mean    37818.843750        928.87500       945.468750    21.406250
# std     45189.884314         56.70737        53.105485    20.731555
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   States_Union Territories  32 non-null     object
#  1   2000-01-INC               32 non-null     int64
#  2   2011-12-INC               32 non-null     int64
#  3   2001 - LIT                32 non-null     float64
#  4   2011- LIT                 32 non-null     float64
#  5   2001 - POP                32 non-null     int64
#  6   2011- POP                 32 non-null     int64
#  7   2001 -SEX_Ratio           32 non-null     int64
#  8   2011 -SEX_Ratio           32 non-null     int64
#  9   2001 -UNEMP               32 non-null     int64
#  10  2011 -UNEMP               32 non-null     int64
#  11  2001 -Poverty             32 non-null     float64
#  12  2011 -Poverty             32 non-null     float64
# dtypes: float64(4), int64(8), object(1)
# ...

# %%
data.columns
# Out:
# Index(['States_Union Territories', '2000-01-INC', '2011-12-INC', '2001 - LIT',
#        '2011- LIT', '2001 - POP', '2011- POP', '2001 -SEX_Ratio',
#        '2011 -SEX_Ratio', '2001 -UNEMP', '2011 -UNEMP', '2001 -Poverty',
#        '2011 -Poverty'],
#       dtype='object')

# %%
INC_data = data[['2000-01-INC', '2011-12-INC']]

# %%
INC_data.describe()
# Out:
#        2000-01-INC    2011-12-INC
# count     32.00000      32.000000
# mean   19696.53125   74792.500000
# std    10191.63120   40960.182286
# min     6415.00000   22582.000000
# 25%    12965.75000   47958.000000
# 50%    16418.00000   66413.000000
# 75%    22781.50000   89198.000000
# max    49771.00000  211570.000000

# %%
INC_data['2000-01-INC'].skew()
# Out:
# 1.5569288822041476

# %%
#The data is positively skewed (right-skewed). This means that the right tail (higher values) is longer or fatter than the left tail. In this case, the mean and median will be greater than the mode.

# %%
INC_data['2000-01-INC'].kurtosis()
# Out:
# 2.1243084910181733

# %%
#The kurtosis of a standard normal distribution is exactly 3. 
#This indicates a platykurtic distribution. It means that the distribution has lighter tails and a flatter peak than a normal distribution. This suggests that the data has fewer extreme values.

# %%
INC_data['2011-12-INC'].skew()
# Out:
# 1.5475035507869082

# %%
INC_data['2011-12-INC'].kurtosis()
# Out:
# 3.035952501101486

# %%
# This indicates a leptokurtic distribution. It means that the distribution has heavier tails and a sharper peak than a normal distribution. This suggests that there are more frequent extreme values (outliers).

# %%
data.hist('2011-12-INC')
# Out:
# array([[<Axes: title={'center': '2011-12-INC'}>]], dtype=object)

# %%
data.hist('2000-01-INC')
# Out:
# array([[<Axes: title={'center': '2000-01-INC'}>]], dtype=object)

# %%
data[['2000-01-INC','2001 - LIT','2001 - POP','2001 -SEX_Ratio','2001 -UNEMP','2001 -Poverty']].describe()
# Out:
#        2000-01-INC  2001 - LIT     2001 - POP  2001 -SEX_Ratio  2001 -UNEMP  \
# count     32.00000   32.000000      32.000000         32.00000    32.000000
# mean   19696.53125   69.810625   32134.437500        928.87500    21.406250
# std    10191.63120   11.149199   38054.631775         56.70737    20.731555
# min     6415.00000   47.000000     356.000000        777.00000     4.000000
# 25%    12965.75000   62.950000    2218.000000        896.75000     8.000000
# 50%    16418.00000   68.975000   20989.500000        934.50000    17.000000
# 75%    22781.50000   78.945000   53765.000000        969.00000    25.000000
# max    49771.00000   90.860000  166198.000000       1058.00000    93.000000
#
#        2001 -Poverty
# count      32.000000
# mean       22.627500
# std        12.279176
# min         3.480000
# 25%        12.180000
# 50%        21.395000
# 75%        32.870000
# max        47.150000

# %%
data[['2011-12-INC','2011- LIT','2011- POP','2011 -SEX_Ratio','2011 -UNEMP','2011 -Poverty']].describe()
# Out:
#          2011-12-INC  2011- LIT      2011- POP  2011 -SEX_Ratio  2011 -UNEMP  \
# count      32.000000  32.000000      32.000000        32.000000    32.000000
# mean    74792.500000  78.240312   37818.843750       945.468750    29.468750
# std     40960.182286   8.733646   45189.884314        53.105485    32.223999
# min     22582.000000  61.800000     381.000000       818.000000     3.000000
# 25%     47958.000000  71.712500    2636.750000       916.500000     9.000000
# 50%     66413.000000  77.465000   25448.000000       949.000000    20.500000
# 75%     89198.000000  86.090000   62958.250000       976.750000    28.250000
# max    211570.000000  94.000000  199812.000000      1084.000000   151.000000
#
#        2011 -Poverty
# count      32.000000
# mean       18.591563
# std        11.086188
# min         1.000000
# 25%         9.855000
# 50%        15.670000
# 75%        29.985000
# max        39.930000

# %%
# data for plot
df_plot_data_2001 = data[['2000-01-INC','2001 - LIT','2001 - POP','2001 -SEX_Ratio','2001 -UNEMP','2001 -Poverty']]

#plotting in seaborn
sns.set_style(style='darkgrid')
plt.figure(figsize = (10,7))
sns.set_context(context ='notebook',font_scale=1)
sns.pairplot(df_plot_data_2001,aspect=1,diag_kind='kde')
plt.tight_layout();

# %%
#Here in the above graph, all the diagonal plots are KDE (Kernel density estimates) rather then histograms and all other are scatter plots.
#The places where the points are clustered tightly, there is high corelation.
#The above scatter plot reveals that the relationship between the variables is non-linear(scattered)

# %%
df_plot_data_2001 = data[['2011-12-INC','2011- LIT','2011- POP','2011 -SEX_Ratio','2011 -UNEMP','2011 -Poverty']]

#plotting in seaborn
sns.set_style(style='darkgrid')
plt.figure(figsize = (10, 8))
sns.set_context(context ='notebook',font_scale=1);
sns.pairplot(df_plot_data_2001,aspect=1,diag_kind='kde');
plt.tight_layout();

# %%
df_corr_11 = data[['2011-12-INC','2011- LIT','2011- POP','2011 -SEX_Ratio','2011 -UNEMP','2011 -Poverty']].corr()

#plotting in seaborn
plt.figure(figsize=(10,7))
sns.heatmap(df_corr_11,cmap='Blues',annot=True,linewidths=0.2,linecolor='white')
plt.title('correlation')
plt.tight_layout()

# %%
#Here in the heatmap, the negative values represent that if one variable increases then the other value decreases i.e that move in opposite direction.
# 1 indicates a perfect positive linear relationship

# %%
df_corr_01 = data[['2000-01-INC','2001 - LIT','2001 - POP','2001 -SEX_Ratio','2001 -UNEMP','2001 -Poverty']].corr()
plt.figure(figsize=(10,7))
sns.heatmap(df_corr_01,cmap='Blues',annot=True,linewidths=0.2,linecolor='white')
plt.title('correlation')
plt.tight_layout()

# %%
# min max scaler function

def min_max(x, y):
    y_min = y.min()
    y_max = y.max()
    MM = (x- y_min)/(y_max - y_min)
    return MM

# %%
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# plotting Indian State's Income vs Literacy rate in year 2001

# data for plot
df_lit_inc_2001 = data[['States_Union Territories', '2000-01-INC', '2001 - LIT']]

# normalization of data because of different scale
min_INC = df_lit_inc_2001['2000-01-INC'].min()
max_INC = df_lit_inc_2001['2000-01-INC'].max()
df_lit_inc_2001['Normalized_INC'] = (df_lit_inc_2001['2000-01-INC'] - min_INC) / (max_INC - min_INC)

min_LIT = df_lit_inc_2001['2001 - LIT'].min()
max_LIT = df_lit_inc_2001['2001 - LIT'].max()
df_lit_inc_2001['Normalized_LIT'] = (df_lit_inc_2001['2001 - LIT'] - min_LIT) / (max_LIT - min_LIT)

# plot
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Normalized_INC', y='Normalized_LIT', data=df_lit_inc_2001, hue='States_Union Territories')
plt.title('Income vs Literacy Rate (2001)')
plt.xlabel('Normalized Income')
plt.ylabel('Normalized Literacy Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# plotting Indian State's Income vs Literacy rate in year 2001

# data for plot
df_lit_inc_2001 = data[['States_Union Territories','2000-01-INC','2001 - LIT']]

# normalization of data because of different scale 
min_INC = df_lit_inc_2001['2000-01-INC'].min()
max_INC = df_lit_inc_2001['2000-01-INC'].max()

min_LIT = df_lit_inc_2001['2001 - LIT'].min()
max_LIT = df_lit_inc_2001['2001 - LIT'].max()

df_lit_inc_2001['2000-01-INC'] = df_lit_inc_2001['2000-01-INC'].apply(lambda x : (x- min_INC)/(max_INC - min_INC))
df_lit_inc_2001['2001 - LIT'] = df_lit_inc_2001['2001 - LIT'].apply(lambda x : (x- min_LIT)/(max_LIT - min_LIT))

# %%
# plotting Indian State's Income vs Literacy rate in year 2001

# data for plot
df_lit_inc_2001 = data[['States_Union Territories','2000-01-INC','2001 - LIT']]

# normalization of data because of different scale 
min_INC = df_lit_inc_2001['2000-01-INC'].min()
max_INC = df_lit_inc_2001['2000-01-INC'].max()

min_LIT = df_lit_inc_2001['2001 - LIT'].min()
max_LIT = df_lit_inc_2001['2001 - LIT'].max()

df_lit_inc_2001['2000-01-INC'] = df_lit_inc_2001['2000-01-INC'].apply(lambda x : (x- min_INC)/(max_INC - min_INC))
df_lit_inc_2001['2001 - LIT'] = df_lit_inc_2001['2001 - LIT'].apply(lambda x : (x- min_LIT)/(max_LIT - min_LIT))

# %%
df_lit_inc_2001.iplot(kind='line',x='States_Union Territories',secondary_y='2001 - LIT',
                      colors=['#53D1BA','#D11E5D'],title='India State Income vs Literacy rate year_2001',
                      xTitle='States in India',yTitle='State Income_SDP',
                      secondary_y_title='literacy rate',theme='pearl')

# %%
# plotting Indian State's Income vs Literacy rate in year 2011

# data for plot
df_lit_inc_2011 = data[['States_Union Territories','2011-12-INC','2011- LIT']]

# normalization
df_lit_inc_2011['2011-12-INC'] = min_max(df_lit_inc_2011['2011-12-INC'],df_lit_inc_2011['2011-12-INC'])
df_lit_inc_2011['2011- LIT'] = min_max(df_lit_inc_2011['2011- LIT'],df_lit_inc_2011['2011- LIT'])

# plot
df_lit_inc_2011.iplot(x ='States_Union Territories',y='2011-12-INC',secondary_y ='2011- LIT',
                      colors = ['#70a3f9','#e7c269'],
                      title = 'India State Income vs Literacy rate year_2011',
                      xTitle='States in India',
                      yTitle ='State Income_SDP',secondary_y_title = 'literacy rate',
                     theme = 'pearl')

# %%
#plotting poverty rate vs literacy rate in the year 2001

pov_lit_rate_2001 = data[['States_Union Territories','2001 -Poverty','2001 - LIT']]

pov_lit_rate_2001.iplot(kind='line',x='States_Union Territories',y='2001 - LIT',secondary_y='2001 -Poverty',secondary_y_title='poverty rate',
                        colors=['#ff6f69','#ffcc5c'],title='Poverty rate vs Literacy rate in each states in the 2001',
                        xTitle='States in India',yTitle='Literacy rate')

# %%
pov_lit_rate_2011 = data[['States_Union Territories','2011 -Poverty','2011- LIT']]
        

pov_lit_rate_2011.sort_values(by='2011 -Poverty').iplot(kind='line',x='States_Union Territories',y='2011- LIT',secondary_y='2011 -Poverty',secondary_y_title='poverty rate',
                        colors=['#ff6f69','#ffcc5c'],title='Poverty rate vs Literacy rate in each states in the year 2011',
                        yTitle='Literacy rate',xTitle='States in India')

# %%
  # data for plot
pov_income_rate_2001 = data[['States_Union Territories','2001 -Poverty','2000-01-INC']]

# normalization
pov_income_rate_2001['2001 -Poverty'] = min_max(pov_income_rate_2001['2001 -Poverty'],pov_income_rate_2001['2001 -Poverty'])
pov_income_rate_2001['2000-01-INC'] = min_max(pov_income_rate_2001['2000-01-INC'],pov_income_rate_2001['2000-01-INC'])
        
# plotting state income vs poverty rate in 2001
pov_income_rate_2001.sort_values(by='2000-01-INC').iplot(kind='bar',x='States_Union Territories',y='2000-01-INC',secondary_y='2001 -Poverty',secondary_y_title='poverty rate',
                        colors=['#1ebbd7','#ffcc5c'],title='state Income vs Poverty rate in each states in the 2001',
                        yTitle='State income',xTitle ='States in india')

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf

data = {
    'States_Union Territories':['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 
        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 
        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 
        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 
        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura', 
        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
    '2001 -Poverty': [15.77, 33.47, 36.09, 42.6, 49.4, 
        4.4, 14.07, 8.74, 7.63, 3.48, 
        36.96, 20.04, 12.72, 37.43, 25.02, 
        28.54, 33.87, 20.4, 19, 47.15, 
        6.16, 15.28, 8.19, 21.12, 34.44, 
        31.15, 13.02, 24.62],
    '2000-01-INC': [ 21808, 10667, 14557, 5740, 11259, 
        43500, 17060, 23201, 24494, 15898, 
        10162, 20467, 27448, 11363, 25811, 
        16736, 11323, 16760, 13760, 10419, 
        26842, 14977, 19986, 19125, 13503, 
        12867, 17745, 19232]
}
# Convert to DataFrame
df = pd.DataFrame(data)

# Min-max normalization function
def min_max(series):
    return (series - series.min()) / (series.max() - series.min())

# Apply normalization
df['2001 -Poverty'] = min_max(df['2001 -Poverty'])
df['2000-01-INC'] = min_max(df['2000-01-INC'])

# Sorting data
df = df.sort_values(by='2000-01-INC')

# Plotting
fig = go.Figure()

# Bar for Income
fig.add_trace(go.Bar(
    x=df['States_Union Territories'],
    y=df['2000-01-INC'],
    name='State Income',
    marker_color='#1ebbd7'
))

# Line for Poverty Rate
fig.add_trace(go.Scatter(
    x=df['States_Union Territories'],
    y=df['2001 -Poverty'],
    name='Poverty Rate',
    mode='lines+markers',
    marker_color='#ffcc5c',
    yaxis='y2'
))

# Create secondary y-axis
fig.update_layout(
    title='State Income vs Poverty Rate in 2001',
    xaxis_title='States in India',
    yaxis_title='State Income',
    yaxis=dict(
        tickmode='linear',
        tick0=0,
        dtick=0.2
    ),
    yaxis2=dict(
        title='Poverty Rate',
        overlaying='y',
        side='right'
    ),
    legend=dict(x=0, y=1.1)
)

fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Load the CSV file
file_path = 'C:\\Users\\DELL\\Downloads\\Unemployment_data.csv'
data = pd.read_csv(file_path)

# Function to perform min-max normalization
def min_max(series):
    return (series - series.min()) / (series.max() - series.min())

# Ensure correct column names are used
# Please adjust column names here based on the actual DataFrame
columns_to_use = ['States_Union Territories', '2011 -Poverty', '2011-12-INC']

# Select relevant columns and drop any rows with missing values
df = data[columns_to_use].dropna()

# Apply normalization
df['2011 -Poverty'] = min_max(df['2011 -Poverty'])
df['2011-12-INC'] = min_max(df['2011-12-INC'])

# Sorting data
df = df.sort_values(by='2011-12-INC')

# Plotting
fig = go.Figure()

# Bar for Income
fig.add_trace(go.Bar(
    x=df['States_Union Territories'],
    y=df['2011-12-INC'],
    name='State Income',
    marker_color='#1ebbd7'
))

# Line for Poverty Rate
fig.add_trace(go.Scatter(
    x=df['States_Union Territories'],
    y=df['2011 -Poverty'],
    name='Poverty Rate',
    mode='lines+markers',
    marker_color='#ffcc5c',
    yaxis='y2'
))

# Create secondary y-axis
fig.update_layout(
    title='State Income vs Poverty Rate in 2011-12',
    xaxis_title='States in India',
    yaxis_title='State Income',
    yaxis=dict(
        tickmode='linear',
        tick0=0,
        dtick=0.2
    ),
    yaxis2=dict(
        title='Poverty Rate',
        overlaying='y',
        side='right'
    ),
    legend=dict(x=0, y=1.1)
)

fig.show()

# %%
# data for plot
pov_population_2001 = data[['States_Union Territories','2001 - POP','2001 -SEX_Ratio']]

pov_population_2001.iplot(kind='line',x='States_Union Territories',secondary_y='2001 - POP',
                      colors=['#53D1BA','#D11E5D'],title='State Population vs State Sex Ratio',
                      xTitle='States in India',yTitle='Sex Ratio',
                      secondary_y_title='Population',theme='pearl')

# %%
# data for plot
pov_population_2011 = data[['States_Union Territories','2011- POP','2011 -SEX_Ratio']]

pov_population_2011.iplot(kind='line',x='States_Union Territories',secondary_y='2011- POP',
                      colors=['#ff6f69','#ffcc5c'],title='State Population vs State Sex Ratio',
                      xTitle='States in India',yTitle='Sex Ratio',
                      secondary_y_title='Population',theme='pearl')

# %%
data.columns
# Out:
# Index(['States_Union Territories', '2000-01-INC', '2011-12-INC', '2001 - LIT',
#        '2011- LIT', '2001 - POP', '2011- POP', '2001 -SEX_Ratio',
#        '2011 -SEX_Ratio', '2001 -UNEMP', '2011 -UNEMP', '2001 -Poverty',
#        '2011 -Poverty'],
#       dtype='object')

# %%
# sorting before plot
data['POP_percentage_change'] = (data['2011- POP'] - data['2001 - POP']) / data['2001 - POP']
data['SEXR_percentage_change'] = (data['2011 -SEX_Ratio'] - data['2001 -SEX_Ratio']) / data['2001 -SEX_Ratio']

df1_sorted = data.sort_values(by='POP_percentage_change',ascending=True)
df2_sorted = data.sort_values(by='SEXR_percentage_change',ascending=True)

# plotting percentage change in states income from 2000 to 2011

df1_sorted.iplot(kind='bar',x='States_Union Territories',
                 y='POP_percentage_change',
                 theme='white',colors='#2997B7',
                title='percentage change in states population from 2000 to 2011', 
                 yTitle = 'percentage')

# %%
data.sort_values(by='2011- POP').iplot(kind='bar',
                            x ='States_Union Territories',y ='2011- POP',
                            secondary_y ='2011 -SEX_Ratio',secondary_y_title='poverty rate',
                            colors =['#b967ff', '#05ffa1'],
                            title ='state Income vs Poverty rate in each states in the 2011',
                            yTitle ='State Population',xTitle ='States in india')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
import joblib
import matplotlib.pyplot as plt

# Separate features and target
features = df.iloc[:, :-1]  # All columns except the last one
target = df.iloc[:, -1]     # The last column

# Identify categorical columns
categorical_cols = features.select_dtypes(include=['object', 'category']).columns
numeric_cols = features.select_dtypes(include=['number']).columns

# Preprocessing for numeric data: scaling
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data: one-hot encoding
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Apply preprocessing
features_processed = preprocessor.fit_transform(features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_processed, target, test_size=0.2, random_state=42)

# Train and evaluate Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)
print(f'Linear Regression MSE: {mse_lr}, R²: {r2_lr}')

# Train and evaluate Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
print(f'Random Forest MSE: {mse_rf}, R²: {r2_rf}')

# Train and evaluate Neural Network (MLP)
nn_model = MLPRegressor(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
nn_model.fit(X_train, y_train)
y_pred_nn = nn_model.predict(X_test)
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)
print(f'Neural Network MSE: {mse_nn}, R²: {r2_nn}')

# Hyperparameter tuning for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30]
}

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

print(f'Best parameters found: {grid_search.best_params_}')
best_rf_model = grid_search.best_estimator_
y_pred_best_rf = best_rf_model.predict(X_test)

mse_best_rf = mean_squared_error(y_test, y_pred_best_rf)
r2_best_rf = r2_score(y_test, y_pred_best_rf)
print(f'Tuned Random Forest MSE: {mse_best_rf}, R²: {r2_best_rf}')
# Out:
# Linear Regression MSE: 0.06506719927482817, R²: -0.40395838729161837
# Random Forest MSE: 0.0654136158395386, R²: -0.41143303576185164
# Neural Network MSE: 0.08363117307591453, R²: -0.8045142281756408
# Best parameters found: {'max_depth': None, 'n_estimators': 100}
# Tuned Random Forest MSE: 0.0654136158395386, R²: -0.41143303576185164

# %%
#Based on the provided metrics, the Linear Regression model performs the best

# %%
import joblib

# Save the preprocessor and the Linear Regression model
joblib.dump(preprocessor, 'preprocessor.pkl')
joblib.dump(lr_model, 'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']

# %%
# save_model.py
import joblib
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# Ensure column names are consistent
data.columns = [col.strip() for col in data.columns]

# Feature selection
features = data[['2000-01-INC', '2011-12-INC', '2001 - LIT', '2011- LIT', '2001 - POP', '2011- POP', '2001 -SEX_Ratio', '2011 -SEX_Ratio', '2001 -UNEMP', '2001 -Poverty']]
target = data['2011 -UNEMP']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Fit a preprocessing pipeline
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the model
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# Save the model and preprocessor
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Bar plot for MSE and R²
def plot_metrics(mse_lr, r2_lr, mse_rf, r2_rf, mse_nn, r2_nn, mse_best_rf, r2_best_rf):
    metrics = {
        'Linear Regression': {'MSE': mse_lr, 'R²': r2_lr},
        'Random Forest': {'MSE': mse_rf, 'R²': r2_rf},
        'Neural Network': {'MSE': mse_nn, 'R²': r2_nn},
        'Tuned Random Forest': {'MSE': mse_best_rf, 'R²': r2_best_rf}
    }

    df_metrics = pd.DataFrame(metrics)

    fig, ax = plt.subplots(2, 1, figsize=(12, 10))

    df_metrics.loc['MSE'].plot(kind='bar', ax=ax[0])
    ax[0].set_title('Mean Squared Error (MSE) Comparison')
    ax[0].set_ylabel('MSE')

    df_metrics.loc['R²'].plot(kind='bar', ax=ax[1])
    ax[1].set_title('R² Score Comparison')
    ax[1].set_ylabel('R²')

    plt.tight_layout()
    plt.show()

# Metrics for each model
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)
mse_best_rf = mean_squared_error(y_test, y_pred_best_rf)
r2_best_rf = r2_score(y_test, y_pred_best_rf)

# Bar plot for MSE and R²
plot_metrics(mse_lr, r2_lr, mse_rf, r2_rf, mse_nn, r2_nn, mse_best_rf, r2_best_rf)

# %%
# IS STATE'S INCOME BASED ON THE EDUCATION OF THE STATE

# %%
# Summary statistics for income and literacy rates
summary_statistics = data[['2000-01-INC', '2011-12-INC', '2001 - LIT', '2011- LIT']].describe()
summary_statistics
# Out:
#        2000-01-INC    2011-12-INC  2001 - LIT  2011- LIT
# count     32.00000      32.000000   32.000000  32.000000
# mean   19696.53125   74792.500000   69.810625  78.240312
# std    10191.63120   40960.182286   11.149199   8.733646
# min     6415.00000   22582.000000   47.000000  61.800000
# 25%    12965.75000   47958.000000   62.950000  71.712500
# 50%    16418.00000   66413.000000   68.975000  77.465000
# 75%    22781.50000   89198.000000   78.945000  86.090000
# max    49771.00000  211570.000000   90.860000  94.000000

# %%
import matplotlib.pyplot as plt

# Histograms
plt.figure(figsize=(14, 6))

# Income 2000-01
plt.subplot(2, 2, 1)
plt.hist(data['2000-01-INC'], bins=10, color='blue', edgecolor='black')
plt.title('Income (2000-01)')
plt.xlabel('Income')
plt.ylabel('Frequency')

# Income 2011-12
plt.subplot(2, 2, 2)
plt.hist(data['2011-12-INC'], bins=10, color='green', edgecolor='black')
plt.title('Income (2011-12)')
plt.xlabel('Income')
plt.ylabel('Frequency')

# Literacy Rate 2001
plt.subplot(2, 2, 3)
plt.hist(data['2001 - LIT'], bins=10, color='purple', edgecolor='black')
plt.title('Literacy Rate (2001)')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Frequency')

# Literacy Rate 2011
plt.subplot(2, 2, 4)
plt.hist(data['2011- LIT'], bins=10, color='red', edgecolor='black')
plt.title('Literacy Rate (2011)')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Scatter plots
plt.figure(figsize=(14, 6))

# Income vs. Literacy Rate (2001)
plt.subplot(1, 2, 1)
plt.scatter(data['2001 - LIT'], data['2000-01-INC'], color='blue')
plt.title('Income (2000-01) vs. Literacy Rate (2001)')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Income')

# Income vs. Literacy Rate (2011)
plt.subplot(1, 2, 2)
plt.scatter(data['2011- LIT'], data['2011-12-INC'], color='green')
plt.title('Income (2011-12) vs. Literacy Rate (2011)')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Income')

plt.tight_layout()
plt.show()

# %%
# Correlation analysis
correlation_2001 = data[['2001 - LIT', '2000-01-INC']].corr()
correlation_2011 = data[['2011- LIT', '2011-12-INC']].corr()

print("Correlation (2001):")
print(correlation_2001)

print("\nCorrelation (2011):")
print(correlation_2011)
# Out:
# Correlation (2001):
#              2001 - LIT  2000-01-INC
# 2001 - LIT     1.000000     0.339893
# 2000-01-INC    0.339893     1.000000
#
# Correlation (2011):
#              2011- LIT  2011-12-INC
# 2011- LIT      1.00000      0.40966
# 2011-12-INC    0.40966      1.00000

# %%
import statsmodels.api as sm

# Regression analysis for 2001
X_2001 = data['2001 - LIT']
Y_2000_01 = data['2000-01-INC']
X_2001 = sm.add_constant(X_2001)
model_2001 = sm.OLS(Y_2000_01, X_2001).fit()
print(model_2001.summary())

# Regression analysis for 2011
X_2011 = data['2011- LIT']
Y_2011_12 = data['2011-12-INC']
X_2011 = sm.add_constant(X_2011)
model_2011 = sm.OLS(Y_2011_12, X_2011).fit()
print(model_2011.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            2000-01-INC   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     3.919
# Date:                Tue, 06 Aug 2024   Prob (F-statistic):             0.0570
# Time:                        12:22:51   Log-Likelihood:                -338.27
# No. Observations:                  32   AIC:                             680.5
# Df Residuals:                      30   BIC:                             683.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1993.7075   1.11e+04     -0.180      0.859   -2.46e+04    2.07e+04
# ...

# %%
#The coefficient in a regression analysis quantifies the relationship between an independent variable (predictor) and the dependent variable (outcome).
#Coefficient for Literacy Rate (2001): 310.7011
#Interpretation: For each percentage point increase in the literacy rate in 2001, the state's income in 2000-2001 is expected to increase by approximately 310.7 units, holding all other factors constant.
R^2 values indicate better-fitting models.

# %%
#Implications
Positive Relationship: Both analyses suggest a positive relationship between literacy rates and state income, with the relationship becoming statistically significant in 2011-2012.
Increasing Impact Over Time: The increase in the coefficient and R-squared value from 2000-2001 to 2011-2012 implies that the impact of literacy rates on income may have grown over time.
Policy Implications: Improving literacy rates could potentially lead to higher state income, supporting the importance of educational policies for economic development.
